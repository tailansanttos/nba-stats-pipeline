# %%
path =  "../data/raw/nba_players.json"
import pandas as pd

# %%
df_jogadores = pd.read_csv(path)
df_jogadores
# Out:
#       PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  \
# 0       1628983     1  Shai Gilgeous-Alexander  1610612760  OKC  76  2598
# 1       1630162     2          Anthony Edwards  1610612750  MIN  79  2871
# 2        203999     3             Nikola Jokić  1610612743  DEN  70  2571
# 3        203507     4    Giannis Antetokounmpo  1610612749  MIL  67  2289
# 4       1628369     5             Jayson Tatum  1610612738  BOS  72  2624
# ...         ...   ...                      ...         ...  ...  ..   ...
# 2820    1628394   536         Anžejs Pasečņiks  1610612764  WAS   1     6
# 2821    1630204   536            Ashton Hagans  1610612750  MIN   2     4
# 2822     204222   536         Greg Whittington  1610612743  DEN   4    12
# 2823     203943   536              Noah Vonleh  1610612751  BKN   4    11
# 2824    1630266   536              Will Magnay  1610612740  NOP   1     3
#
#       FGM   FGA  FG_PCT  ...  AST  STL  BLK  TOV   PF   PTS   EFF  AST_TOV  \
# ...

# %%
df_jogadores.shape
# Out:
# (2825, 29)

# %%
df_jogadores.head
# Out:
# <bound method NDFrame.head of       PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  \
# 0       1628983     1  Shai Gilgeous-Alexander  1610612760  OKC  76  2598
# 1       1630162     2          Anthony Edwards  1610612750  MIN  79  2871
# 2        203999     3             Nikola Jokić  1610612743  DEN  70  2571
# 3        203507     4    Giannis Antetokounmpo  1610612749  MIL  67  2289
# 4       1628369     5             Jayson Tatum  1610612738  BOS  72  2624
# ...         ...   ...                      ...         ...  ...  ..   ...
# 2820    1628394   536         Anžejs Pasečņiks  1610612764  WAS   1     6
# 2821    1630204   536            Ashton Hagans  1610612750  MIN   2     4
# 2822     204222   536         Greg Whittington  1610612743  DEN   4    12
# 2823     203943   536              Noah Vonleh  1610612751  BKN   4    11
# 2824    1630266   536              Will Magnay  1610612740  NOP   1     3
#
# ...

# %%
df_jogadores.dtypes
# Out:
# PLAYER_ID      int64
# RANK           int64
# PLAYER           str
# TEAM_ID        int64
# TEAM             str
# GP             int64
# MIN            int64
# FGM            int64
# FGA            int64
# FG_PCT       float64
# FG3M           int64
# FG3A           int64
# FG3_PCT      float64
# FTM            int64
# FTA            int64
# FT_PCT       float64
# OREB           int64
# DREB           int64
# REB            int64
# AST            int64
# STL            int64
# BLK            int64
# TOV            int64
# PF             int64
# PTS            int64
# EFF            int64
# AST_TOV      float64
# STL_TOV      float64
# temporada        str
# dtype: object

# %%
df_jogadores.isnull().sum()
# Out:
# PLAYER_ID    0
# RANK         0
# PLAYER       0
# TEAM_ID      0
# TEAM         0
# GP           0
# MIN          0
# FGM          0
# FGA          0
# FG_PCT       0
# FG3M         0
# FG3A         0
# FG3_PCT      0
# FTM          0
# FTA          0
# FT_PCT       0
# OREB         0
# DREB         0
# REB          0
# AST          0
# STL          0
# BLK          0
# TOV          0
# PF           0
# PTS          0
# EFF          0
# AST_TOV      0
# STL_TOV      0
# temporada    0
# dtype: int64

# %%
df_jogadores.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2825 entries, 0 to 2824
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PLAYER_ID  2825 non-null   int64
#  1   RANK       2825 non-null   int64
#  2   PLAYER     2825 non-null   str
#  3   TEAM_ID    2825 non-null   int64
#  4   TEAM       2825 non-null   str
#  5   GP         2825 non-null   int64
#  6   MIN        2825 non-null   int64
#  7   FGM        2825 non-null   int64
#  8   FGA        2825 non-null   int64
#  9   FG_PCT     2825 non-null   float64
#  10  FG3M       2825 non-null   int64
#  11  FG3A       2825 non-null   int64
#  12  FG3_PCT    2825 non-null   float64
#  13  FTM        2825 non-null   int64
#  14  FTA        2825 non-null   int64
#  15  FT_PCT     2825 non-null   float64
#  16  OREB       2825 non-null   int64
#  17  DREB       2825 non-null   int64
#  18  REB        2825 non-null   int64
#  19  AST        2825 non-null   int64
# ...
